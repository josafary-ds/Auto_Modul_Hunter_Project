# %%
import pandas as pd
import numpy as np
import os
import feets
import warnings

# %%
print(np.__version__)
# Out:
# 1.26.4

# %% [markdown]
# ## Application test with 1 light curve

# %%
df = pd.read_csv('../LightCurves/001152358_22.dat', sep=' ', header=None, names=['time', 'flux'])
df.head()
# Out:
#           time      flux
# 0  1900.414603  0.955040
# 1  1900.415992  1.013595
# 2  1900.417381  0.996042
# 3  1900.418770  1.031510
# 4  1900.420158  0.972890

# %%
time, flux = (df.time, df.flux)
lc_feets = [time, flux]

# %%
# %%time
fs = feets.FeatureSpace(data=['magnitude', 'time'], only=['Amplitude', 'Eta_e', 'LinearTrend', 'Mean', 'Meanvariance', 'MedianAbsDev', 'PercentAmplitude', 'PeriodLS', 'Period_fit', 'Psi_CS', 'Psi_eta', 'Std'])
features, values = fs.extract(*lc_feets)
table = pd.DataFrame(data=[values], columns=[features])
table
# Out:
# WARNING: AstropyDeprecationWarning: Importing LombScargle from astropy.stats has been deprecated and will no longer be supported in future. Please import this class from the astropy.timeseries module instead [astropy.stats.lombscargle]
# Wall time: 9.31 s
#   Amplitude     Eta_e LinearTrend      Mean Meanvariance MedianAbsDev  \
# 0  0.038367  2.781633    0.000008  0.999896      0.01949     0.013162
#
#   PercentAmplitude  PeriodLS Period_fit    Psi_CS  Psi_eta       Std
# 0         0.067496  0.000091        1.0  0.013116  2.01383  0.019488

# %% [markdown]
# ## Application with a test data set

# %%
input_dir = os.listdir('LC_test')

dataframes = []

for file in input_dir:
    id_sec = file.split('.')[0] 
    id_name, sec_name = id_sec.split('_')

    df_1 = pd.DataFrame([[id_name, sec_name]], columns=['id', 'sector'])
    dataframes.append(df_1)

df_final = pd.concat(dataframes, ignore_index=True)

df_final
# Out:
#           id sector
# 0  001152358     22
# 1  004289780     06
# 2  004289780     32
# 3  004373827     20
# 4  004373827     44
# 5  004373827     45
# 6  004373827     46
# 7  004373827     47
# 8  004373827     60
# 9  004491131     20

# %%
warnings.simplefilter("ignore")

input_dir = os.listdir('LC_test')

table = []

for file in input_dir:
    df = pd.read_csv(f'LC_test/{file}', sep=' ', header=None, names=['time', 'flux'])
    time, flux = (df.time, df.flux)
    lc_feets = [time, flux]

    fs = feets.FeatureSpace(data=['magnitude', 'time'], only=['Amplitude', 'Eta_e', 'LinearTrend', 'Mean', 'Meanvariance', 'MedianAbsDev', 'PercentAmplitude', 'PeriodLS', 'Period_fit', 'Psi_CS', 'Psi_eta', 'Std'])
    features, values = fs.extract(*lc_feets)

    id_sec = file.split('.')[0] 
    id_name, sec_name = id_sec.split('_')

    df_1 = pd.DataFrame(data=[[id_name, sec_name, *values]], columns=['id', 'sector']+list(features))
    table.append(df_1)

feets_table = pd.concat(table, ignore_index=True)

feets_table
# Out:
#           id sector  Amplitude     Eta_e   LinearTrend      Mean  \
# 0  001152358     22   0.038367  2.781633  8.398356e-06  0.999896
# 1  004289780     06   0.003984  0.027998 -2.574445e-06  1.000369
# 2  004289780     32   0.004005  0.026885  3.039774e-06  1.000378
# 3  004373827     20   0.065865  2.627467 -1.699160e-05  0.999851
# 4  004373827     44   0.070649  2.481889  3.691981e-05  1.000068
# 5  004373827     45   0.062061  2.524782 -1.545700e-05  1.000097
# 6  004373827     46   0.060725  2.504261  2.451540e-06  1.000440
# 7  004373827     47   0.068740  2.602666  2.811777e-06  0.999550
# 8  004373827     60   0.071001  3.407248 -6.563091e-05  1.000195
# 9  004491131     20   0.068080  0.857899 -6.655137e-07  1.001776
#
#    Meanvariance  MedianAbsDev  PercentAmplitude  PeriodLS  Period_fit  \
# 0      0.019490      0.013162          0.067496  0.000091    1.000000
# 1      0.002672      0.002411          0.006699  0.853793    0.000000
# 2      0.002702      0.002441          0.006885  0.854841    0.000000
# 3      0.033532      0.022580          0.117115  0.000043    1.000000
# 4      0.035810      0.024006          0.123233  0.000106    1.000000
# 5      0.031706      0.021571          0.109070  0.000040    0.999997
# 6      0.031051      0.020825          0.108453  0.000040    1.000000
# 7      0.035040      0.023848          0.122027  0.000036    1.000000
# 8      0.035988      0.024467          0.125629  0.000107    0.000000
# 9      0.037168      0.028319          0.125210  0.230257    0.000000
#
#      Psi_CS   Psi_eta       Std
# 0  0.013116  2.013830  0.019488
# 1  0.230237  0.050262  0.002673
# 2  0.233032  0.037314  0.002703
# 3  0.019476  1.983205  0.033527
# 4  0.015542  2.024841  0.035813
# 5  0.016329  1.981143  0.031709
# 6  0.013413  1.995121  0.031064
# 7  0.014799  1.978180  0.035024
# 8  0.023045  1.994281  0.035995
# 9  0.187549  0.665165  0.037234
